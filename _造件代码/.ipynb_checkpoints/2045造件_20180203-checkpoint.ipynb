# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from tool.func_new import *

# %%
parcel_path = r'F:\造件代码\file\2045OD_Matrix.xlsx'  # 文件路径
# =============================================================
parcel_sheet_name = 'Parcel pcs'                # parcel表名
#==============================================================
Irregular_sheet_name = 'Irregular pcs'          # Irregular表名
# =============================================================
nc_sheet_name = 'NC pcs'                        # NC表名
# =============================================================
isb_sheet_name = 'Mail bag pcs'                 # isb表名
# =============================================================
parse_cols = 'B:YS'                             # 读取列范围
parse_skip_num = 57                              # 跳过行数
parse_cols_split = 5                            # 列索引切片
air_model_list = ['I', 'D', 'INF']             # 始发地，空侧
land_model_list = ['R']                        # 始发地，陆侧
parcel_type_name = 'parcel'                     # 包裹类型

# 完整列名
parcel_col_list=['small_id','parcel_id','parcel_type','src_type','dest_type','plate_num','uld_num',
                 'arrive_time','send_time','plan_disallow_tm','actual_disallow_tm','src_apt',
                 'dest_apt','dest_city_code','ident_des_zno','plate_priority','is_mixture','inserted_on','modified_on']

# 按照数据库结构，修改对应的列名
db_columns_modify = {'model':'src_type', 'desc_model':'dest_type',
                     'Flight_ID':'plate_num','city':'dest_city_code',
                     'api':'dest_apt','apt':'src_apt',
                     'landing_time':'arrive_time'}

# %% [markdown]
# # 读取parcel_pcs表

# %%
# 读取parcel_pcs表
df_parcel = read_excel(excel_path=parcel_path,
                       sheet_name=parcel_sheet_name,
                       read_columns=parse_cols,
                       fill_val=0,
                      skip_footer=parse_skip_num)

# %%
# df_parcel.loc[df_parcel.model.isin(['R']),:]
df_parcel
# Out:
#        apt model     Flight ID       payload     landing time    10_PEK_D  \
# 0      WUX     D           224  15801.457012  00:10:36.585000    0.000000
# 1      HGH     D            37  19052.423708  00:13:32.195000    0.000000
# 2      PVG     D            75  15018.120988  00:16:27.805000   32.264388
# 3      SZX     D         104-1  17323.418717  00:19:23.415000   14.913241
# 4      WUX     D           226  15798.509123  00:20:51.220000    0.000000
# 5      PVG     D            79  21306.170474  00:22:19.024000   45.773406
# 6      JJN     D            51  27497.517854  00:25:14.634000  603.009767
# 7      SZX     D            98  23356.831217  00:28:10.244000   20.107235
# 8      CAN     D             3  22046.891258  00:31:05.854000  134.799026
# 9      SZX     D            95  23356.831217  00:34:01.463000   20.107235
# 10     CAN     D             4  20754.741329  00:35:29.268000  126.898567
# 11     NGB     D            60  10198.631652  00:36:57.073000   16.788989
# 12     SJW     D            93  14158.220907  00:38:24.878000    0.000000
# 13     TAO     D           116  14794.195536  00:39:52.683000    0.000000
# 14     SZX     D            97  17316.955071  00:42:48.293000   14.907677
# 15     CAN     D             5  24368.307348  00:45:43.902000  148.992621
# 16     PEK     D            67  13894.602831  00:48:39.512000    0.000000
# 17     CAN     D             6  24368.307274  00:50:07.317000  148.992619
# 18     SZX     D            99  22896.125330  00:51:35.122000   19.710627
# 19     PVG     D            77  13019.296410  00:53:02.927000   27.970186
# 20     TAO     D           115  11009.732923  00:54:30.732000    0.000000
# 21     CAN     D             7  24368.307274  00:57:26.341000  148.992619
# 22     SZX     D           100  17323.418717  00:58:54.146000   14.913241
0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 192  1.914217e-05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 193  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 194  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 195  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 196  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 197  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 198  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 199  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 200  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 201  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 202  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 203  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 204  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# [205 rows x 668 columns]

# %%
# 取列名，替换空格
col_list = list(df_parcel.columns.str.replace(' ','_'))

# 重置列名
df_parcel.columns = col_list

# %%
# melt参数
id_vars  = col_list[:parse_cols_split]
value_vars = col_list[parse_cols_split:]

# 整理parcel pcs表格，即每行的目的地只有一个
df_parcel = pd.melt(df_parcel,
                    id_vars=id_vars,
                    value_vars=value_vars,
                    var_name='desc_city_api_model',
                    value_name='parcel_sum')

# %%
# 重新读取desc_city_api_model列，生成DataFrame对象，与原数据拼接
a=df_parcel['desc_city_api_model'].str.split('_')
b=np.array(a)
c=list(b)
df_desc= pd.DataFrame(c,columns=['city','api','desc_model'])

# %%
# 将目的地的city,api，model的df对象与df_parcel合并,并删除desc_city_api_model列
df_parcel = pd.concat([df_parcel, df_desc], axis=1).drop('desc_city_api_model',axis='columns')

# 增加parcel_type列，
df_parcel['parcel_type'] = parcel_type_name

#只读取国际:I，国内:D，INF出发数据
df_parcel_air = df_parcel.loc[df_parcel.model.isin(air_model_list), :]

#只读取陆侧出发数据
df_parcel_landland = df_parcel.loc[df_parcel.model.isin(['R']), :]


# 空侧精度控制
df_parcel_air['parcel_sum']=df_parcel_air['parcel_sum'].apply(lambda x:parcel_round_air(x))

# 陆侧精度控制
df_parcel_landland['parcel_sum']=df_parcel_landland['parcel_sum'].apply(lambda x:parcel_round_land(x))
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# d:\python\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# df_parcel_landland

# %%
# 根据包裹的数量，造small_id,parcel_id


# 读取parcel_sum列,每个去向的包裹数量
series_sum_air = df_parcel_air['parcel_sum'].fillna(0)
# print(series_sum_air)

#空测包裹数量
len_sum_air = series_sum_air.sum()
print('和为：%s'%len_sum_air)

arr_sum = list(np.array(series_sum_air,dtype=np.int64))
# print(arr_sum)
# 临时存放包裹
new_list = []

# 包裹的columns
df_parcel_columns_list =  list(df_parcel_air.columns)
print(df_parcel_columns_list)
# 
arr1_list_parcel_air = list(np.array(df_parcel_air))
print(arr1_list_parcel_air)
for i,val in enumerate(arr1_list_parcel_air):
    if arr_sum[i] > 0:
        for i in range(arr_sum[i]):
            new_list.append(val)
print('new_list长度：%s' % len(new_list))
# Out:
# 和为：398361.0
# ['apt', 'model', 'Flight_ID', 'payload', 'landing_time', 'parcel_sum', 'city', 'api', 'desc_model', 'parcel_type']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# 根据包裹数量生成包裹
df_parcel_obj = pd.DataFrame(np.array(new_list),columns=df_parcel_columns_list)

# # 制造small_id
# id_list =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air)+1000000)]
# df_id = pd.DataFrame({"small_id":id_list})

# # 合并small_id
# df_parcel_new = pd.concat([df_id,df_parcel_obj],axis=1)

# %%
# 修改列名（按照数据库）
df_parcel_obj.rename(columns=db_columns_modify, inplace = True)

# print(df_parcel_new.columns)

# 按数据库字段，重组columns结构
air_parcel_data_new = df_parcel_obj.loc[df_parcel_obj.src_type.isin(air_model_list), parcel_col_list]

# 格式化时间
air_parcel_data_new['arrive_time'] = air_parcel_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))

# %%
# air_parcel_data_new1 # 空侧parcel

# %% [markdown]
# ### 读取陆侧parcel

# %%
# 读取parcel_sum列,每个去向的包裹数量
series_sum_land = df_parcel_landland['parcel_sum'].fillna(0)

len_sum_land = series_sum_land.sum()
print('和为：%s'%len_sum_land)
arr_sum_land = list(np.array(series_sum_land,dtype=np.int64))

# 临时存放包裹
new_list_land = []

# 包裹的columns
df_parcel_columns_list_land =  list(df_parcel_landland.columns)

arr1_list_parcel_land = list(np.array(df_parcel_landland))
for i,val in enumerate(arr1_list_parcel_land):
    if arr_sum_land[i] > 0:
        for i in range(arr_sum_land[i]):
            new_list_land.append(val)
print('new_list_land长度：%s' % len(new_list_land))
# Out:
# 和为：106075.0
# new_list_land长度：106075

# %%
# 根据包裹数量生成包裹
df_parcel_obj_land = pd.DataFrame(np.array(new_list_land),columns=df_parcel_columns_list_land)

# # 制造small_id
# id_list_land =["{i:0>{n}}".format(i=i,n=8) for i in range(int(len_sum_air),int(len_sum_air)+1000000)]
# df_id = pd.DataFrame({"small_id":id_list_land})

# # 合并small_id
# df_parcel_new_land = pd.concat([df_id,df_parcel_obj_land],axis=1)

# %%
# id_list_land

# %%
# 修改列名（按照数据库）
df_parcel_obj_land.rename(columns=db_columns_modify, inplace = True)

# print(df_parcel_new_land.columns)

# 按数据库字段，重组columns结构
land_parcel_data_new = df_parcel_obj_land.loc[df_parcel_obj_land.src_type.isin(land_model_list), parcel_col_list]

# 格式化时间
land_parcel_data_new['arrive_time'] = land_parcel_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))

# %%
# land_parcel_data_new1

# %% [markdown]
# ### 拼接parcel类空侧与陆侧

# %%
total_parcel=pd.concat([air_parcel_data_new,land_parcel_data_new])

# %% [markdown]
# # 读取smalls bag pcs表

# %%
small_sheet_name = 'Small bag pcs'             # small表名
small_parse_cols = 'B:YS'                       # 读取列范围
small_parse_skip_num = 57                        # 跳过行数
small_parse_cols_split = 5                      # 列索引切片
small_air_model_list = ['I', 'D', 'INF']        # 始发地，空侧
small_land_model_list = ['R']                   # 始发地，陆侧
small_type_name = 'small'               # 包裹类型

# %%
# 读取smalls bag pcs表
df_small = read_excel(excel_path=parcel_path,
                       sheet_name=small_sheet_name,
                       read_columns=small_parse_cols,
                       fill_val=0,
                     skip_footer=small_parse_skip_num)

# %%
df_small
# Out:
#        apt model     Flight ID       payload     landing time    10_PEK_D  \
# 0      WUX     D           224  15801.457012  00:10:36.585000    0.000000
# 1      HGH     D            37  19052.423708  00:13:32.195000    0.000000
# 2      PVG     D            75  15018.120988  00:16:27.805000    5.489630
# 3      SZX     D         104-1  17323.418717  00:19:23.415000    2.537416
# 4      WUX     D           226  15798.509123  00:20:51.220000    0.000000
# 5      PVG     D            79  21306.170474  00:22:19.024000    7.788125
# 6      JJN     D            51  27497.517854  00:25:14.634000  102.599212
# 7      SZX     D            98  23356.831217  00:28:10.244000    3.421149
# 8      CAN     D             3  22046.891258  00:31:05.854000   22.935406
# 9      SZX     D            95  23356.831217  00:34:01.463000    3.421149
0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 6    4.190124e-01  1.138895e+00  1.308714e+00  1.878641e+01
# 7    4.850137e-01  6.069504e-01  7.139150e-01  2.082615e+00
# 8    4.952966e-01  7.713200e-01  1.062670e+00  8.926051e-01
# 9    4.850137e-01  6.069504e-01  7.139150e-01  2.082615e+00
# 10   4.662677e-01  7.261136e-01  1.000388e+00  8.402902e-01
# 11   2.025673e-01  2.988650e-01  3.834440e-01  1.054617e+00
# 12   4.823966e-03  9.484394e-03  3.059614e-02  1.895805e-02
# 13   9.052420e-02  1.419288e-01  1.701448e-01  1.972063e-01
# 14   3.595934e-01  4.499982e-01  5.293027e-01  1.544068e+00
# 15   5.474487e-01  8.525358e-01  1.174563e+00  9.865915e-01
# 16   7.481067e-03  1.136977e-02  1.280913e-02  1.799874e-02
# 17   5.474486e-01  8.525357e-01  1.174563e+00  9.865915e-01
# 18   4.754470e-01  5.949785e-01  6.998333e-01  2.041536e+00
# 19   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 20   6.736745e-02  1.056224e-01  1.266205e-01  1.467595e-01
# 21   5.474486e-01  8.525357e-01  1.174563e+00  9.865915e-01
# 22   3.597276e-01  4.501662e-01  5.295003e-01  1.544645e+00
# 23   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 24   6.265261e-02  7.793136e-02  8.343088e-02  3.147904e-02
# 25   5.153013e-02  7.444709e-02  1.164698e-01  3.461697e-02
# 26   3.597276e-01  4.501662e-01  5.295003e-01  1.544645e+00
# 27   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 28   2.243564e-17  3.010487e-17  3.823892e-17  8.298506e-17
# 29   1.108003e-05  9.829780e-06  3.272341e-05  0.000000e+00
# ..            ...           ...           ...           ...
# 175  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 176  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 177  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 178  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 179  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 180  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 181  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 182  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 183  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 184  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 185  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 186  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 187  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 188  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 189  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 190  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 191  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 192  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 193  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 194  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 195  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 196  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 197  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 198  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 199  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 200  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 201  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 202  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 203  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 204  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# [205 rows x 668 columns]

# %%
# 取列名，替换空格
col_list_small = list(df_small.columns.str.replace(' ','_'))

# 重置列名
df_small.columns = col_list

# %%
# melt参数
id_vars_small  = col_list[:parse_cols_split]
value_vars_small = col_list[parse_cols_split:]

# 整理parcel pcs表格，即每行的目的地只有一个
df_small = pd.melt(df_small,
                    id_vars=id_vars_small,
                    value_vars=value_vars_small,
                    var_name='desc_city_api_model',
                    value_name='parcel_sum')

# %%
# df_small.head

# %%
# 重新读取desc_city_api_model列，生成DataFrame对象，与原数据拼接
a_small=df_small['desc_city_api_model'].str.split('_')
b_small=np.array(a_small)
c_small=list(b_small)
df_desc_small= pd.DataFrame(c_small,columns=['city','api','desc_model'])

# 将目的地的city,api，model的df对象与df_small合并,并删除desc_city_api_model列
df_small = pd.concat([df_small, df_desc_small], axis=1).drop('desc_city_api_model',axis='columns')

# 增加parcel_type列，
df_small['parcel_type'] = small_type_name

#只读取国际:I，国内:D，INF出发数据
df_small_air = df_small.loc[df_small.model.isin(small_air_model_list), :]

#只读取陆侧出发数据
df_small_land_land = df_small.loc[df_small.model.isin(['R']), :]


# 空侧精度控制
df_small_air['parcel_sum']=df_small_air['parcel_sum'].apply(lambda x:small_round_air(x))

# 陆侧精度控制
df_small_land_land['parcel_sum']=df_small_land_land['parcel_sum'].apply(lambda x:small_round_land(x))


# 根据包裹的数量，造small_id,parcel_id


# small类型空测包裹

# 读取parcel_sum列,每个去向的包裹数量
series_sum_air_small = df_small_air['parcel_sum'].fillna(0)
len_sum_air_small = series_sum_air_small.sum()
print('和为：%s'%len_sum_air_small)
arr_sum_small = list(np.array(series_sum_air_small,dtype=np.int64))

# 临时存放包裹
new_list_small = []

# 包裹的columns
df_small_columns_list =  list(df_small_air.columns)

arr1_list_small_air = list(np.array(df_small_air))
for i,val in enumerate(arr1_list_small_air):
    if arr_sum_small[i] > 0:
        for i in range(arr_sum_small[i]*20):
            new_list_small.append(val)
print('new_list_small长度：%s' % len(new_list_small))


# 根据包裹数量生成包裹
df_small_obj = pd.DataFrame(np.array(new_list_small),columns=df_small_columns_list)

# # 制造small_id
# id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# df_id_small = pd.DataFrame({"small_id":id_list_small})

# # 合并small_id
# df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# 修改列名（按照数据库）
df_small_obj.rename(columns=db_columns_modify, inplace = True)

# 按数据库字段，重组columns结构
air_small_data_new = df_small_obj.loc[df_small_obj.src_type.isin(small_air_model_list), parcel_col_list]

# 格式化时间
air_small_data_new['arrive_time'] = air_small_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))




# small类型陆测包裹


# 读取parcel_sum列,每个去向的包裹数量
series_sum_land_small = df_small_land_land['parcel_sum'].fillna(0)

len_sum_air_small_land = series_sum_land_small.sum()
print('和为：%s'%len_sum_air_small_land)

arr_sum_small_land = list(np.array(series_sum_land_small,dtype=np.int64))

# 临时存放包裹
new_list_small_land = []

# 包裹的columns
df_small_columns_list =  list(df_small_land_land.columns)

arr1_list_small_land = list(np.array(df_small_land_land))
for i,val in enumerate(arr1_list_small_land):
    if arr_sum_small_land[i] > 0:
        for i in range(arr_sum_small_land[i]*20):
            new_list_small_land.append(val)
print('new_list_small_land长度：%s' % len(new_list_small_land))


# 根据包裹数量生成包裹
df_small_obj_land = pd.DataFrame(np.array(new_list_small_land),columns=df_small_columns_list)

# # 制造small_id
# id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# df_id_small = pd.DataFrame({"small_id":id_list_small})

# # 合并small_id
# df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# 修改列名（按照数据库）
df_small_obj_land.rename(columns=db_columns_modify, inplace = True)

# 按数据库字段，重组columns结构
land_small_data_new = df_small_obj_land.loc[df_small_obj_land.src_type.isin(['R']), parcel_col_list]

# 格式化时间
land_small_data_new['arrive_time'] = land_small_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# d:\python\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 和为：38232.0
# new_list_small长度：764640
# 和为：17963.0
# new_list_small_land长度：359260

# %%
# small类型包裹
total_small=pd.concat([land_small_data_new,air_small_data_new])

# %%
total_small
# Out:
#         small_id  parcel_id parcel_type src_type dest_type plate_num  uld_num  \
# 0            NaN        NaN       small        R         D    IP-E05      NaN
# 1            NaN        NaN       small        R         D    IP-E05      NaN
# 2            NaN        NaN       small        R         D    IP-E05      NaN
# 3            NaN        NaN       small        R         D    IP-E05      NaN
# 4            NaN        NaN       small        R         D    IP-E05      NaN
# 5            NaN        NaN       small        R         D    IP-E05      NaN
# 6            NaN        NaN       small        R         D    IP-E05      NaN
# 7            NaN        NaN       small        R         D    IP-E05      NaN
# 8            NaN        NaN       small        R         D    IP-E05      NaN
# 9            NaN        NaN       small        R         D    IP-E05      NaN
# 10           NaN        NaN       small        R         D    IP-E05      NaN
# 11           NaN        NaN       small        R         D    IP-E05      NaN
# 12           NaN        NaN       small        R         D    IP-E05      NaN
# 13           NaN        NaN       small        R         D    IP-E05      NaN
# 14           NaN        NaN       small        R         D    IP-E05      NaN
# 15           NaN        NaN       small        R         D    IP-E05      NaN
# 16           NaN        NaN       small        R         D    IP-E05      NaN
# 17           NaN        NaN       small        R         D    IP-E05      NaN
# 18           NaN        NaN       small        R         D    IP-E05      NaN
# 19           NaN        NaN       small        R         D    IP-E05      NaN
# 20           NaN        NaN       small        R         D    IP-E05      NaN
# 21           NaN        NaN       small        R         D    IP-E05      NaN
# 22           NaN        NaN       small        R         D    IP-E05      NaN
# 23           NaN        NaN       small        R         D    IP-E05      NaN
# 24           NaN        NaN       small        R         D    IP-E05      NaN
# 25           NaN        NaN       small        R         D    IP-E05      NaN
# 26           NaN        NaN       small        R         D    IP-E05      NaN
# 27           NaN        NaN       small        R         D    IP-E05      NaN
# 28           NaN        NaN       small        R         D    IP-E05      NaN
# 29           NaN        NaN       small        R         D    IP-E05      NaN
# ...          ...        ...         ...      ...       ...       ...      ...
# 764610       NaN        NaN       small        I         R       120      NaN
# 764611       NaN        NaN       small        I         R       120      NaN
# 764612       NaN        NaN       small        I         R       120      NaN
# 764613       NaN        NaN       small        I         R       120      NaN
# 764614       NaN        NaN       small        I         R       120      NaN
# 764615       NaN        NaN       small        I         R       120      NaN
# 764616       NaN        NaN       small        I         R       120      NaN
# 764617       NaN        NaN       small        I         R       120      NaN
# 764618       NaN        NaN       small        I         R       120      NaN
# 764619       NaN        NaN       small        I         R       120      NaN
# 764620       NaN        NaN       small        I         R       128      NaN
# 764621       NaN        NaN       small        I         R       128      NaN
# 764622       NaN        NaN       small        I         R       128      NaN
# 764623       NaN        NaN       small        I         R       128      NaN
# 764624       NaN        NaN       small        I         R       128      NaN
# 764625       NaN        NaN       small        I         R       128      NaN
# 764626       NaN        NaN       small        I         R       128      NaN
# 764627       NaN        NaN       small        I         R       128      NaN
# 764628       NaN        NaN       small        I         R       128      NaN
# 764629       NaN        NaN       small        I         R       128      NaN
# 764630       NaN        NaN       small        I         R       128      NaN
# 764631       NaN        NaN       small        I         R       128      NaN
# 764632       NaN        NaN       small        I         R       128      NaN
# 764633       NaN        NaN       small        I         R       128      NaN
# 764634       NaN        NaN       small        I         R       128      NaN
# 764635       NaN        NaN       small        I         R       128      NaN
# 764636       NaN        NaN       small        I         R       128      NaN
# 764637       NaN        NaN       small        I         R       128      NaN
# 764638       NaN        NaN       small        I         R       128      NaN
# 764639       NaN        NaN       small        I         R       128      NaN
#
#        arrive_time  send_time  plan_disallow_tm  actual_disallow_tm src_apt  \
# 0         00:00:00        NaN               NaN                 NaN   7112R
# 1         00:00:00        NaN               NaN                 NaN   7112R
# 2         00:00:00        NaN               NaN                 NaN   7112R
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# 5               NaN          NaN
# 6               NaN          NaN
# 7               NaN          NaN
# 8               NaN          NaN
# 9               NaN          NaN
# 10              NaN          NaN
# 11              NaN          NaN
# 12              NaN          NaN
# 13              NaN          NaN
# 14              NaN          NaN
# 15              NaN          NaN
# 16              NaN          NaN
# 17              NaN          NaN
# 18              NaN          NaN
# 19              NaN          NaN
# 20              NaN          NaN
# 21              NaN          NaN
# 22              NaN          NaN
# 23              NaN          NaN
# 24              NaN          NaN
# 25              NaN          NaN
# 26              NaN          NaN
# 27              NaN          NaN
# 28              NaN          NaN
# 29              NaN          NaN
# ...             ...          ...
# 764610          NaN          NaN
# 764611          NaN          NaN
# 764612          NaN          NaN
# 764613          NaN          NaN
# 764614          NaN          NaN
# 764615          NaN          NaN
# 764616          NaN          NaN
# 764617          NaN          NaN
# 764618          NaN          NaN
# 764619          NaN          NaN
# 764620          NaN          NaN
# 764621          NaN          NaN
# 764622          NaN          NaN
# 764623          NaN          NaN
# 764624          NaN          NaN
# 764625          NaN          NaN
# 764626          NaN          NaN
# 764627          NaN          NaN
# 764628          NaN          NaN
# 764629          NaN          NaN
# 764630          NaN          NaN
# 764631          NaN          NaN
# 764632          NaN          NaN
# 764633          NaN          NaN
# 764634          NaN          NaN
# 764635          NaN          NaN
# 764636          NaN          NaN
# 764637          NaN          NaN
# 764638          NaN          NaN
# 764639          NaN          NaN
#
# [1123900 rows x 19 columns]

# %% [markdown]
# # 读取Irregular pcs表

# %%
irregular_sheet_name = 'Irregular pcs'             # irregular表名
irregular_parse_cols = 'B:YS'                       # 读取列范围
irregular_parse_skip_num = 57                        # 跳过行数
irregular_parse_cols_split = 5                      # 列索引切片
irregular_air_model_list = ['I', 'D', 'INF']        # 始发地，空侧
irregular_land_model_list = ['R']                   # 始发地，陆侧
irregular_type_name = 'irregular'               # 包裹类型


# 读取irregular bag pcs表
df_irregular = read_excel(excel_path=parcel_path,
                       sheet_name=irregular_sheet_name,
                       read_columns=irregular_parse_cols,
                       fill_val=0,
                     skip_footer=irregular_parse_skip_num)

# 取列名，替换空格
col_list_irregular = list(df_irregular.columns.str.replace(' ','_'))

# 重置列名
df_irregular.columns = col_list_irregular

# melt参数
id_vars_irregular  = col_list_irregular[:parse_cols_split]
value_vars_irregular = col_list_irregular[parse_cols_split:]

# 整理parcel pcs表格，即每行的目的地只有一个
df_irregular = pd.melt(df_irregular,
                    id_vars=id_vars_irregular,
                    value_vars=value_vars_irregular,
                    var_name='desc_city_api_model',
                    value_name='parcel_sum')


# 重新读取desc_city_api_model列，生成DataFrame对象，与原数据拼接
a_irregular=df_irregular['desc_city_api_model'].str.split('_')
b_irregular=np.array(a_irregular)
c_irregular=list(b_irregular)
df_desc_irregular= pd.DataFrame(c_irregular,columns=['city','api','desc_model'])

# 将目的地的city,api，model的df对象与df_irregular合并,并删除desc_city_api_model列
df_irregular = pd.concat([df_irregular, df_desc_irregular], axis=1).drop('desc_city_api_model',axis='columns')

# 增加parcel_type列，
df_irregular['parcel_type'] = irregular_type_name

#只读取国际:I，国内:D，INF出发数据
df_irregular_air = df_irregular.loc[df_irregular.model.isin(irregular_air_model_list), :]

#只读取陆侧出发数据
df_irregular_land_land = df_irregular.loc[df_irregular.model.isin(['R']), :]


# 空侧精度控制
df_irregular_air['parcel_sum']=df_irregular_air['parcel_sum'].apply(lambda x:irregular_round_air(x))

# 陆侧精度控制
df_irregular_land_land['parcel_sum']=df_irregular_land_land['parcel_sum'].apply(lambda x:irregular_round_land(x))


# 根据包裹的数量，造irregular_id,parcel_id


# irregular类型空测包裹

# 读取parcel_sum列,每个去向的包裹数量
series_sum_air_irregular = df_irregular_air['parcel_sum'].fillna(0)
len_sum_air_irregular = series_sum_air_irregular.sum()
print('和为：%s'%len_sum_air_irregular)
arr_sum_irregular = list(np.array(series_sum_air_irregular,dtype=np.int64))

# 临时存放包裹
new_list_irregular = []

# 包裹的columns
df_irregular_columns_list =  list(df_irregular_air.columns)

arr1_list_irregular_air = list(np.array(df_irregular_air))
for i,val in enumerate(arr1_list_irregular_air):
    if arr_sum_irregular[i] > 0:
        for i in range(arr_sum_irregular[i]):
            new_list_irregular.append(val)
print('new_list_irregular长度：%s' % len(new_list_irregular))


# 根据包裹数量生成包裹
df_irregular_obj = pd.DataFrame(np.array(new_list_irregular),columns=df_irregular_columns_list)

# # 制造small_id
# id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# df_id_small = pd.DataFrame({"small_id":id_list_small})

# # 合并small_id
# df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# 修改列名（按照数据库）
df_irregular_obj.rename(columns=db_columns_modify, inplace = True)

# 按数据库字段，重组columns结构
air_irregular_data_new = df_irregular_obj.loc[df_irregular_obj.src_type.isin(irregular_air_model_list), parcel_col_list]

# 格式化时间
air_irregular_data_new['arrive_time'] = air_irregular_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))




# irregular类型陆测包裹


# 读取parcel_sum列,每个去向的包裹数量
series_sum_land_irregular = df_irregular_land_land['parcel_sum'].fillna(0)

len_sum_air_irregular_land = series_sum_land_irregular.sum()
print('和为：%s'%len_sum_air_irregular_land)

arr_sum_irregular_land = list(np.array(series_sum_land_irregular,dtype=np.int64))

# 临时存放包裹
new_list_irregular_land = []

# 包裹的columns
df_irregular_columns_list =  list(df_irregular_land_land.columns)

arr1_list_irregular_land = list(np.array(df_irregular_land_land))
for i,val in enumerate(arr1_list_irregular_land):
    if arr_sum_irregular_land[i] > 0:
        for i in range(arr_sum_irregular_land[i]):
            new_list_irregular_land.append(val)
print('new_list_irregular_land长度：%s' % len(new_list_irregular_land))


# 根据包裹数量生成包裹
df_irregular_obj_land = pd.DataFrame(np.array(new_list_irregular_land),columns=df_irregular_columns_list)

# # 制造small_id
# id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# df_id_small = pd.DataFrame({"small_id":id_list_small})

# # 合并small_id
# df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# 修改列名（按照数据库）
df_irregular_obj_land.rename(columns=db_columns_modify, inplace = True)

# 按数据库字段，重组columns结构
land_irregular_data_new = df_irregular_obj_land.loc[df_irregular_obj_land.src_type.isin(['R']), parcel_col_list]

# 格式化时间
land_irregular_data_new['arrive_time'] = land_irregular_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# d:\python\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 和为：32575.0
# new_list_irregular长度：32575
# 和为：13571.0
# new_list_irregular_land长度：13571

# %%
# irregular类型包裹
total_irregular=pd.concat([land_irregular_data_new,air_irregular_data_new])

# %%
# total_irregular.head

# %% [markdown]
# # 读取NC表

# %%
nc_sheet_name = 'NC pcs'             # nc表名
nc_parse_cols = 'B:YS'                       # 读取列范围
nc_parse_skip_num = 57                        # 跳过行数
nc_parse_cols_split = 5                      # 列索引切片
nc_air_model_list = ['I', 'D', 'INF']        # 始发地，空侧
nc_land_model_list = ['R']                   # 始发地，陆侧
nc_type_name = 'nc'               # 包裹类型


# 读取nc bag pcs表
df_nc = read_excel(excel_path=parcel_path,
                       sheet_name=nc_sheet_name,
                       read_columns=nc_parse_cols,
                       fill_val=0,
                     skip_footer=nc_parse_skip_num)

# 取列名，替换空格
col_list_nc = list(df_nc.columns.str.replace(' ','_'))

# 重置列名
df_nc.columns = col_list_nc

# melt参数
id_vars_nc  = col_list_nc[:parse_cols_split]
value_vars_nc = col_list_nc[parse_cols_split:]

# 整理parcel pcs表格，即每行的目的地只有一个
df_nc = pd.melt(df_nc,
                    id_vars=id_vars_nc,
                    value_vars=value_vars_nc,
                    var_name='desc_city_api_model',
                    value_name='parcel_sum')


# 重新读取desc_city_api_model列，生成DataFrame对象，与原数据拼接
a_nc=df_nc['desc_city_api_model'].str.split('_')
b_nc=np.array(a_nc)
c_nc=list(b_nc)
df_desc_nc= pd.DataFrame(c_nc,columns=['city','api','desc_model'])

# 将目的地的city,api，model的df对象与df_nc合并,并删除desc_city_api_model列
df_nc = pd.concat([df_nc, df_desc_nc], axis=1).drop('desc_city_api_model',axis='columns')

# 增加parcel_type列，
df_nc['parcel_type'] = nc_type_name

#只读取国际:I，国内:D，INF出发数据
df_nc_air = df_nc.loc[df_nc.model.isin(nc_air_model_list), :]

#只读取陆侧出发数据
df_nc_land_land = df_nc.loc[df_nc.model.isin(['R']), :]


# 空侧精度控制
df_nc_air['parcel_sum']=df_nc_air['parcel_sum'].apply(lambda x:nc_round_air(x))

# 陆侧精度控制
df_nc_land_land['parcel_sum']=df_nc_land_land['parcel_sum'].apply(lambda x:nc_round_land(x))


# 根据包裹的数量，造nc_id,parcel_id


# nc类型空测包裹

# 读取parcel_sum列,每个去向的包裹数量
series_sum_air_nc = df_nc_air['parcel_sum'].fillna(0)
len_sum_air_nc = series_sum_air_nc.sum()
print('和为：%s'%len_sum_air_nc)
arr_sum_nc = list(np.array(series_sum_air_nc,dtype=np.int64))

# 临时存放包裹
new_list_nc = []

# 包裹的columns
df_nc_columns_list =  list(df_nc_air.columns)

arr1_list_nc_air = list(np.array(df_nc_air))
for i,val in enumerate(arr1_list_nc_air):
    if arr_sum_nc[i] > 0:
        for i in range(arr_sum_nc[i]):
            new_list_nc.append(val)
print('new_list_nc长度：%s' % len(new_list_nc))


# 根据包裹数量生成包裹
df_nc_obj = pd.DataFrame(np.array(new_list_nc),columns=df_nc_columns_list)

# # 制造small_id
# id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# df_id_small = pd.DataFrame({"small_id":id_list_small})

# # 合并small_id
# df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# 修改列名（按照数据库）
df_nc_obj.rename(columns=db_columns_modify, inplace = True)

# 按数据库字段，重组columns结构
air_nc_data_new = df_nc_obj.loc[df_nc_obj.src_type.isin(nc_air_model_list), parcel_col_list]

# 格式化时间
air_nc_data_new['arrive_time'] = air_nc_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))




# nc类型陆测包裹


# 读取parcel_sum列,每个去向的包裹数量
series_sum_land_nc = df_nc_land_land['parcel_sum'].fillna(0)

len_sum_air_nc_land = series_sum_land_nc.sum()
print('和为：%s'%len_sum_air_nc_land)

arr_sum_nc_land = list(np.array(series_sum_land_nc,dtype=np.int64))

# 临时存放包裹
new_list_nc_land = []

# 包裹的columns
df_nc_columns_list =  list(df_nc_land_land.columns)

arr1_list_nc_land = list(np.array(df_nc_land_land))
for i,val in enumerate(arr1_list_nc_land):
    if arr_sum_nc_land[i] > 0:
        for i in range(arr_sum_nc_land[i]):
            new_list_nc_land.append(val)
print('new_list_nc_land长度：%s' % len(new_list_nc_land))


# 根据包裹数量生成包裹
df_nc_obj_land = pd.DataFrame(np.array(new_list_nc_land),columns=df_nc_columns_list)

# # 制造small_id
# id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# df_id_small = pd.DataFrame({"small_id":id_list_small})

# # 合并small_id
# df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# 修改列名（按照数据库）
df_nc_obj_land.rename(columns=db_columns_modify, inplace = True)

# 按数据库字段，重组columns结构
land_nc_data_new = df_nc_obj_land.loc[df_nc_obj_land.src_type.isin(['R']), parcel_col_list]

# 格式化时间
land_nc_data_new['arrive_time'] = land_nc_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 和为：4372.0
# new_list_nc长度：4372
# 和为：240.0
# new_list_nc_land长度：240
# d:\python\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# NC类型包裹
total_nc=pd.concat([land_nc_data_new,air_nc_data_new])

# %%
# total_nc

# %% [markdown]
# # 读取mail表

# %%
isb_sheet_name = 'Mail pcs'             # isb表名
isb_parse_cols = 'B:YS'                       # 读取列范围
isb_parse_skip_num = 57                        # 跳过行数
isb_parse_cols_split = 5                      # 列索引切片
isb_air_model_list = ['I', 'D', 'INF']        # 始发地，空侧
isb_land_model_list = ['R']                   # 始发地，陆侧
isb_type_name = 'isb'               # 包裹类型


# 读取isb bag pcs表
df_isb = read_excel(excel_path=parcel_path,
                       sheet_name=isb_sheet_name,
                       read_columns=isb_parse_cols,
                       fill_val=0,
                     skip_footer=isb_parse_skip_num)

# 取列名，替换空格
col_list_isb = list(df_isb.columns.str.replace(' ','_'))

# 重置列名
df_isb.columns = col_list_isb

# melt参数
id_vars_isb  = col_list_isb[:parse_cols_split]
value_vars_isb = col_list_isb[parse_cols_split:]

# 整理parcel pcs表格，即每行的目的地只有一个
df_isb = pd.melt(df_isb,
                    id_vars=id_vars_isb,
                    value_vars=value_vars_isb,
                    var_name='desc_city_api_model',
                    value_name='parcel_sum')


# 重新读取desc_city_api_model列，生成DataFrame对象，与原数据拼接
a_isb=df_isb['desc_city_api_model'].str.split('_')
b_isb=np.array(a_isb)
c_isb=list(b_isb)
df_desc_isb= pd.DataFrame(c_isb,columns=['city','api','desc_model'])

# 将目的地的city,api，model的df对象与df_isb合并,并删除desc_city_api_model列
df_isb = pd.concat([df_isb, df_desc_isb], axis=1).drop('desc_city_api_model',axis='columns')

# 增加parcel_type列，
df_isb['parcel_type'] = isb_type_name

#只读取国际:I，国内:D，INF出发数据
df_isb_air = df_isb.loc[df_isb.model.isin(isb_air_model_list), :]

#只读取陆侧出发数据
df_isb_land_land = df_isb.loc[df_isb.model.isin(['R']), :]


# 空侧精度控制
df_isb_air['parcel_sum']=df_isb_air['parcel_sum'].apply(lambda x:myround_air(x,isb_sheet_name))

# 陆侧精度控制
df_isb_land_land['parcel_sum']=df_isb_land_land['parcel_sum'].apply(lambda x:myround_land(x,isb_sheet_name))


# 根据包裹的数量，造isb_id,parcel_id


# isb类型空测包裹

# 读取parcel_sum列,每个去向的包裹数量
series_sum_air_isb = df_isb_air['parcel_sum'].fillna(0)
len_sum_air_isb = series_sum_air_isb.sum()
print('和为：%s'%len_sum_air_isb)
# arr_sum_isb = list(np.array(series_sum_air_isb,dtype=np.int64))

# # 临时存放包裹
# new_list_isb = []

# # 包裹的columns
# df_isb_columns_list =  list(df_isb_air.columns)

# arr1_list_isb_air = list(np.array(df_isb_air))
# for i,val in enumerate(arr1_list_isb_air):
#     if arr_sum_isb[i] > 0:
#         for i in range(arr_sum_isb[i]):
#             new_list_isb.append(val)
# print('new_list_isb长度：%s' % len(new_list_isb))


# # 根据包裹数量生成包裹
# df_isb_obj = pd.DataFrame(np.array(new_list_isb),columns=df_isb_columns_list)

# # # 制造small_id
# # id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# # df_id_small = pd.DataFrame({"small_id":id_list_small})

# # # 合并small_id
# # df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# # 修改列名（按照数据库）
# df_isb_obj.rename(columns=db_columns_modify, inplace = True)

# # 按数据库字段，重组columns结构
# air_isb_data_new = df_isb_obj.loc[df_isb_obj.src_type.isin(isb_air_model_list), parcel_col_list]

# # 格式化时间
# air_isb_data_new['arrive_time'] = air_isb_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))




# # isb类型陆测包裹


# # 读取parcel_sum列,每个去向的包裹数量
# series_sum_land_isb = df_isb_land_land['parcel_sum'].fillna(0)

# len_sum_air_isb_land = series_sum_land_isb.sum()
# print('和为：%s'%len_sum_air_isb_land)


# arr_sum_isb_land = list(np.array(series_sum_land_isb,dtype=np.int64))

# # 临时存放包裹
# new_list_isb_land = []

# # 包裹的columns
# df_isb_columns_list =  list(df_isb_land_land.columns)

# arr1_list_isb_land = list(np.array(df_isb_land_land))
# for i,val in enumerate(arr1_list_isb_land):
#     if arr_sum_isb_land[i] > 0:
#         for i in range(arr_sum_isb_land[i]):
#             new_list_isb_land.append(val)
# print('new_list_isb_land长度：%s' % len(new_list_isb_land))


# # 根据包裹数量生成包裹
# df_isb_obj_land = pd.DataFrame(np.array(new_list_isb_land),columns=df_isb_columns_list)

# # # 制造small_id
# # id_list_small =["{i:0>{n}}".format(i=i,n=8) for i in range(1000000,int(len_sum_air_small)+1000000)]
# # df_id_small = pd.DataFrame({"small_id":id_list_small})

# # # 合并small_id
# # df_small_new = pd.concat([df_id_small,df_small_obj],axis=1)


# # 修改列名（按照数据库）
# df_isb_obj_land.rename(columns=db_columns_modify, inplace = True)

# # 按数据库字段，重组columns结构
# land_isb_data_new = df_isb_obj_land.loc[df_isb_obj_land.src_type.isin(['R']), parcel_col_list]

# # 格式化时间
# land_isb_data_new['arrive_time'] = land_isb_data_new['arrive_time'].apply(lambda x: x.strftime('%H:%M:%S'))
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 和为：0
# d:\python\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# # isb类型包裹
# total_isb=pd.concat([land_isb_data_new,air_isb_data_new])

# %%
# 合并所有类型包裹

# %%
total=pd.concat([total_parcel,total_small,total_irregular,total_nc])

# %%
total
# Out:
#       small_id  parcel_id parcel_type src_type dest_type plate_num  uld_num  \
# 0          NaN        NaN      parcel        D         D        75      NaN
# 1          NaN        NaN      parcel        D         D        75      NaN
# 2          NaN        NaN      parcel        D         D        75      NaN
# 3          NaN        NaN      parcel        D         D        75      NaN
# 4          NaN        NaN      parcel        D         D        75      NaN
# 5          NaN        NaN      parcel        D         D        75      NaN
# 6          NaN        NaN      parcel        D         D        75      NaN
# 7          NaN        NaN      parcel        D         D        75      NaN
# 8          NaN        NaN      parcel        D         D        75      NaN
# 9          NaN        NaN      parcel        D         D        75      NaN
# 10         NaN        NaN      parcel        D         D        75      NaN
# 11         NaN        NaN      parcel        D         D        75      NaN
# 12         NaN        NaN      parcel        D         D        75      NaN
# 13         NaN        NaN      parcel        D         D        75      NaN
# 14         NaN        NaN      parcel        D         D        75      NaN
# 15         NaN        NaN      parcel        D         D        75      NaN
# 16         NaN        NaN      parcel        D         D        75      NaN
# 17         NaN        NaN      parcel        D         D        75      NaN
# 18         NaN        NaN      parcel        D         D        75      NaN
# 19         NaN        NaN      parcel        D         D        75      NaN
# 20         NaN        NaN      parcel        D         D        75      NaN
# 21         NaN        NaN      parcel        D         D        75      NaN
# 22         NaN        NaN      parcel        D         D        75      NaN
# 23         NaN        NaN      parcel        D         D        75      NaN
# 24         NaN        NaN      parcel        D         D        75      NaN
# 25         NaN        NaN      parcel        D         D        75      NaN
# 26         NaN        NaN      parcel        D         D        75      NaN
# 27         NaN        NaN      parcel        D         D        75      NaN
# 28         NaN        NaN      parcel        D         D        75      NaN
# 29         NaN        NaN      parcel        D         D        75      NaN
# ...        ...        ...         ...      ...       ...       ...      ...
# 4342       NaN        NaN          nc        I         R        49      NaN
# 4343       NaN        NaN          nc        D         R     104-1      NaN
# 4344       NaN        NaN          nc        D         R        98      NaN
# 4345       NaN        NaN          nc        D         R         3      NaN
# 4346       NaN        NaN          nc        D         R        95      NaN
# 4347       NaN        NaN          nc        D         R         4      NaN
# 4348       NaN        NaN          nc        D         R        97      NaN
# 4349       NaN        NaN          nc        D         R         5      NaN
# 4350       NaN        NaN          nc        D         R         6      NaN
# 4351       NaN        NaN          nc        D         R        99      NaN
# 4352       NaN        NaN          nc        D         R         7      NaN
# 4353       NaN        NaN          nc        D         R       100      NaN
# 4354       NaN        NaN          nc        D         R       101      NaN
# 4355       NaN        NaN          nc        D         R       102      NaN
# 4356       NaN        NaN          nc        D         R       103      NaN
# 4357       NaN        NaN          nc        D         R        96      NaN
# 4358       NaN        NaN          nc        D         R     104-1      NaN
# 4359       NaN        NaN          nc        D         R        51      NaN
# 4360       NaN        NaN          nc        D         R        98      NaN
# 4361       NaN        NaN          nc        D         R        95      NaN
# 4362       NaN        NaN          nc        D         R        97      NaN
# 4363       NaN        NaN          nc        D         R        99      NaN
# 4364       NaN        NaN          nc        D         R       100      NaN
# 4365       NaN        NaN          nc        D         R       101      NaN
# 4366       NaN        NaN          nc        D         R       102      NaN
# 4367       NaN        NaN          nc        D         R       103      NaN
# 4368       NaN        NaN          nc        D         R        61      NaN
# 4369       NaN        NaN          nc        D         R       230      NaN
# 4370       NaN        NaN          nc        D         R        50      NaN
# 4371       NaN        NaN          nc        D         R        96      NaN
#
#      arrive_time  send_time  plan_disallow_tm  actual_disallow_tm src_apt  \
# 0       00:16:27        NaN               NaN                 NaN     PVG
# 1       00:16:27        NaN               NaN                 NaN     PVG
# 2       00:16:27        NaN               NaN                 NaN     PVG
# 3       00:16:27        NaN               NaN                 NaN     PVG
# 4       00:16:27        NaN               NaN                 NaN     PVG
# 5       00:16:27        NaN               NaN                 NaN     PVG
# 6       00:16:27        NaN               NaN                 NaN     PVG
# 7       00:16:27        NaN               NaN                 NaN     PVG
# 8       00:16:27        NaN               NaN                 NaN     PVG
# 9       00:16:27        NaN               NaN                 NaN     PVG
# 10      00:16:27        NaN               NaN                 NaN     PVG
# 11      00:16:27        NaN               NaN                 NaN     PVG
# 12      00:16:27        NaN               NaN                 NaN     PVG
# 13      00:16:27        NaN               NaN                 NaN     PVG
# 14      00:16:27        NaN               NaN                 NaN     PVG
# 15      00:16:27        NaN               NaN                 NaN     PVG
# 16      00:16:27        NaN               NaN                 NaN     PVG
# 17      00:16:27        NaN               NaN                 NaN     PVG
# 18      00:16:27        NaN               NaN                 NaN     PVG
# 19      00:16:27        NaN               NaN                 NaN     PVG
# 20      00:16:27        NaN               NaN                 NaN     PVG
# 21      00:16:27        NaN               NaN                 NaN     PVG
# 22      00:16:27        NaN               NaN                 NaN     PVG
# 23      00:16:27        NaN               NaN                 NaN     PVG
# 24      00:16:27        NaN               NaN                 NaN     PVG
# 25      00:16:27        NaN               NaN                 NaN     PVG
# 26      00:16:27        NaN               NaN                 NaN     PVG
# 27      00:16:27        NaN               NaN                 NaN     PVG
# 28      00:16:27        NaN               NaN                 NaN     PVG
# 29      00:16:27        NaN               NaN                 NaN     PVG
# ...          ...        ...               ...                 ...     ...
# 4342    00:04:45        NaN               NaN                 NaN     ICN
# 4343    00:19:23        NaN               NaN                 NaN     SZX
# 4344    00:28:10        NaN               NaN                 NaN     SZX
# 4345    00:31:05        NaN               NaN                 NaN     CAN
# 4346    00:34:01        NaN               NaN                 NaN     SZX
# 4347    00:35:29        NaN               NaN                 NaN     CAN
# 4348    00:42:48        NaN               NaN                 NaN     SZX
# 4349    00:45:43        NaN               NaN                 NaN     CAN
# 4350    00:50:07        NaN               NaN                 NaN     CAN
# 4351    00:51:35        NaN               NaN                 NaN     SZX
# 4354      717            717            NaN             NaN         NaN
# 4355      717            717            NaN             NaN         NaN
# 4356      717            717            NaN             NaN         NaN
# 4357      717            717            NaN             NaN         NaN
# 4358      792            792            NaN             NaN         NaN
# 4359      792            792            NaN             NaN         NaN
# 4360      792            792            NaN             NaN         NaN
# 4361      792            792            NaN             NaN         NaN
# 4362      792            792            NaN             NaN         NaN
# 4363      792            792            NaN             NaN         NaN
# 4364      792            792            NaN             NaN         NaN
# 4365      792            792            NaN             NaN         NaN
# 4366      792            792            NaN             NaN         NaN
# 4367      792            792            NaN             NaN         NaN
# 4368      792            792            NaN             NaN         NaN
# 4369      792            792            NaN             NaN         NaN
# 4370      792            792            NaN             NaN         NaN
# 4371      792            792            NaN             NaN         NaN
#
#       inserted_on  modified_on
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# 5             NaN          NaN
# 6             NaN          NaN
# 7             NaN          NaN
# 8             NaN          NaN
# 9             NaN          NaN
# 10            NaN          NaN
# 11            NaN          NaN
# 12            NaN          NaN
# 13            NaN          NaN
# 14            NaN          NaN
# 15            NaN          NaN
# 16            NaN          NaN
# 17            NaN          NaN
# 18            NaN          NaN
# 19            NaN          NaN
# 20            NaN          NaN
# 21            NaN          NaN
# 22            NaN          NaN
# 23            NaN          NaN
# 24            NaN          NaN
# 25            NaN          NaN
# 26            NaN          NaN
# 27            NaN          NaN
# 28            NaN          NaN
# 29            NaN          NaN
# ...           ...          ...
# 4342          NaN          NaN
# 4343          NaN          NaN
# 4344          NaN          NaN
# 4345          NaN          NaN
# 4346          NaN          NaN
# 4347          NaN          NaN
# 4348          NaN          NaN
# 4349          NaN          NaN
# 4350          NaN          NaN
# 4351          NaN          NaN
# 4352          NaN          NaN
# 4353          NaN          NaN
# 4354          NaN          NaN
# 4355          NaN          NaN
# 4356          NaN          NaN
# 4357          NaN          NaN
# 4358          NaN          NaN
# 4359          NaN          NaN
# 4360          NaN          NaN
# 4361          NaN          NaN
# 4362          NaN          NaN
# 4363          NaN          NaN
# 4364          NaN          NaN
# 4365          NaN          NaN
# 4366          NaN          NaN
# 4367          NaN          NaN
# 4368          NaN          NaN
# 4369          NaN          NaN
# 4370          NaN          NaN
# 4371          NaN          NaN
#
# [1679094 rows x 19 columns]

# %%
total.shape
# Out:
# (1679094, 19)

# %%
# 制造small_id
id_list_small =["{i:0>{n}}".format(i=i,n=7) for i in range(1000000,int(total.shape[0])+1000000)]
df_id_small = pd.DataFrame({"small_id":id_list_small})

# %%
total['small_id']=id_list_small

# 整理索引
total.reset_index(drop=True,inplace=True)

# %%
# # 纯票类的 parcel ,irregular ,nc
# total_a=total.loc[total.parcel_type.isin(['parcel','irregular','nc'])]
# # 包类的 small ,isb
# total_b=total.loc[total.parcel_type.isin(['small','isb'])]

# total_a['parcel_id']=total_a['small_id']
# Out:
# d:\python\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# 调整时间格式
total['arrive_time']=total['arrive_time'].apply(lambda x:"2018-02-07 "+x if int(x[0:2])>12 else "2018-02-08 "+x)

# %%
total
# Out:
#         small_id  parcel_id parcel_type src_type dest_type plate_num  uld_num  \
# 0        1000000        NaN      parcel        D         D        75      NaN
# 1        1000001        NaN      parcel        D         D        75      NaN
# 2        1000002        NaN      parcel        D         D        75      NaN
# 3        1000003        NaN      parcel        D         D        75      NaN
# 4        1000004        NaN      parcel        D         D        75      NaN
# 5        1000005        NaN      parcel        D         D        75      NaN
# 6        1000006        NaN      parcel        D         D        75      NaN
# 7        1000007        NaN      parcel        D         D        75      NaN
# 8        1000008        NaN      parcel        D         D        75      NaN
# 9        1000009        NaN      parcel        D         D        75      NaN
# 10       1000010        NaN      parcel        D         D        75      NaN
# 11       1000011        NaN      parcel        D         D        75      NaN
# 12       1000012        NaN      parcel        D         D        75      NaN
# 13       1000013        NaN      parcel        D         D        75      NaN
# 14       1000014        NaN      parcel        D         D        75      NaN
# 15       1000015        NaN      parcel        D         D        75      NaN
# 16       1000016        NaN      parcel        D         D        75      NaN
# 17       1000017        NaN      parcel        D         D        75      NaN
# 18       1000018        NaN      parcel        D         D        75      NaN
# 19       1000019        NaN      parcel        D         D        75      NaN
# 20       1000020        NaN      parcel        D         D        75      NaN
# 21       1000021        NaN      parcel        D         D        75      NaN
# 22       1000022        NaN      parcel        D         D        75      NaN
# 23       1000023        NaN      parcel        D         D        75      NaN
# 24       1000024        NaN      parcel        D         D        75      NaN
# 25       1000025        NaN      parcel        D         D        75      NaN
# 26       1000026        NaN      parcel        D         D        75      NaN
# 27       1000027        NaN      parcel        D         D        75      NaN
# 28       1000028        NaN      parcel        D         D        75      NaN
# 29       1000029        NaN      parcel        D         D        75      NaN
# ...          ...        ...         ...      ...       ...       ...      ...
# 1679064  2679064        NaN          nc        I         R        49      NaN
# 1679065  2679065        NaN          nc        D         R     104-1      NaN
# 1679066  2679066        NaN          nc        D         R        98      NaN
# 1679067  2679067        NaN          nc        D         R         3      NaN
# 1679068  2679068        NaN          nc        D         R        95      NaN
# 1679069  2679069        NaN          nc        D         R         4      NaN
# 1679070  2679070        NaN          nc        D         R        97      NaN
# 1679071  2679071        NaN          nc        D         R         5      NaN
# 1679072  2679072        NaN          nc        D         R         6      NaN
# 1679073  2679073        NaN          nc        D         R        99      NaN
# 1679074  2679074        NaN          nc        D         R         7      NaN
# 1679075  2679075        NaN          nc        D         R       100      NaN
# 1679076  2679076        NaN          nc        D         R       101      NaN
# 1679077  2679077        NaN          nc        D         R       102      NaN
# 1679078  2679078        NaN          nc        D         R       103      NaN
# 1679079  2679079        NaN          nc        D         R        96      NaN
# 1679080  2679080        NaN          nc        D         R     104-1      NaN
# 1679081  2679081        NaN          nc        D         R        51      NaN
# 1679082  2679082        NaN          nc        D         R        98      NaN
# 1679083  2679083        NaN          nc        D         R        95      NaN
# 1679084  2679084        NaN          nc        D         R        97      NaN
# 1679085  2679085        NaN          nc        D         R        99      NaN
# 1679086  2679086        NaN          nc        D         R       100      NaN
# 1679087  2679087        NaN          nc        D         R       101      NaN
# 1679088  2679088        NaN          nc        D         R       102      NaN
# 1679089  2679089        NaN          nc        D         R       103      NaN
# 1679078     SZX      717            717            NaN             NaN
# 1679079     SZX      717            717            NaN             NaN
# 1679080     SZX      792            792            NaN             NaN
# 1679081     JJN      792            792            NaN             NaN
# 1679082     SZX      792            792            NaN             NaN
# 1679083     SZX      792            792            NaN             NaN
# 1679084     SZX      792            792            NaN             NaN
# 1679085     SZX      792            792            NaN             NaN
# 1679086     SZX      792            792            NaN             NaN
# 1679087     SZX      792            792            NaN             NaN
# 1679088     SZX      792            792            NaN             NaN
# 1679089     SZX      792            792            NaN             NaN
# 1679090     NGB      792            792            NaN             NaN
# 1679091     XMN      792            792            NaN             NaN
# 1679092     JJN      792            792            NaN             NaN
# 1679093     SZX      792            792            NaN             NaN
#
#          is_mixture  inserted_on  modified_on
# 0               NaN          NaN          NaN
# 1               NaN          NaN          NaN
# 2               NaN          NaN          NaN
# 3               NaN          NaN          NaN
# 4               NaN          NaN          NaN
# 5               NaN          NaN          NaN
# 6               NaN          NaN          NaN
# 7               NaN          NaN          NaN
# 8               NaN          NaN          NaN
# 9               NaN          NaN          NaN
# 10              NaN          NaN          NaN
# 11              NaN          NaN          NaN
# 12              NaN          NaN          NaN
# 13              NaN          NaN          NaN
# 14              NaN          NaN          NaN
# 15              NaN          NaN          NaN
# 16              NaN          NaN          NaN
# 17              NaN          NaN          NaN
# 18              NaN          NaN          NaN
# 19              NaN          NaN          NaN
# 20              NaN          NaN          NaN
# 21              NaN          NaN          NaN
# 22              NaN          NaN          NaN
# 23              NaN          NaN          NaN
# 24              NaN          NaN          NaN
# 25              NaN          NaN          NaN
# 26              NaN          NaN          NaN
# 27              NaN          NaN          NaN
# 28              NaN          NaN          NaN
# 29              NaN          NaN          NaN
# ...             ...          ...          ...
# 1679064         NaN          NaN          NaN
# 1679065         NaN          NaN          NaN
# 1679066         NaN          NaN          NaN
# 1679067         NaN          NaN          NaN
# 1679068         NaN          NaN          NaN
# 1679069         NaN          NaN          NaN
# 1679070         NaN          NaN          NaN
# 1679071         NaN          NaN          NaN
# 1679072         NaN          NaN          NaN
# 1679073         NaN          NaN          NaN
# 1679074         NaN          NaN          NaN
# 1679075         NaN          NaN          NaN
# 1679076         NaN          NaN          NaN
# 1679077         NaN          NaN          NaN
# 1679078         NaN          NaN          NaN
# 1679079         NaN          NaN          NaN
# 1679080         NaN          NaN          NaN
# 1679081         NaN          NaN          NaN
# 1679082         NaN          NaN          NaN
# 1679083         NaN          NaN          NaN
# 1679084         NaN          NaN          NaN
# 1679085         NaN          NaN          NaN
# 1679086         NaN          NaN          NaN
# 1679087         NaN          NaN          NaN
# 1679088         NaN          NaN          NaN
# 1679089         NaN          NaN          NaN
# 1679090         NaN          NaN          NaN
# 1679091         NaN          NaN          NaN
# 1679092         NaN          NaN          NaN
# 1679093         NaN          NaN          NaN
#
# [1679094 rows x 19 columns]

# %%
# engine = create_engine('mysql+pymysql://root:root@localhost:3306/my_db?charset=utf8')
# od_parcel.to_sql('i_od_parcel_2025_detail',engine,if_exists='append',chunksize=20000,index=False)

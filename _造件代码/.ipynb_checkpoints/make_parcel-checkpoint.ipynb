# %%
import pandas as pd
import pymysql
import numpy as np

from sqlalchemy import create_engine

# %% [markdown]
# ### 读取数据库

# %%
engine = create_engine('mysql+pymysql://lujian:lujian@SF00627265LAS.sf.com:3306/ezhouhub_tf')
od_parcel = pd.read_sql_table("i_od_parcel_2025v31_add",con=engine)
# Out:
# c:\users\89005076\appdata\local\programs\python\python36\lib\site-packages\pymysql\cursors.py:166: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 496")
#   result = self._query(query)

# %%
# od_parcel['is_mixtrue']=0
# od_parcel['parcel_id']=np.nan
od_parcel.head(10)
# Out:
#    small_id parcel_id parcel_type src_type dest_type plate_num      uld_num  \
# 0  10000001  10000001      parcel        D         D    CSS224  ULD40245208
# 1  10000002  10000002      parcel        D         D    CSS224  ULD40245211
# 2  10000003  10000003      parcel        D         D    CSS224  ULD40245188
# 3  10000004  10000004      parcel        D         D    CSS224  ULD40245208
# 4  10000005  10000005      parcel        D         D    CSS224  ULD40245200
# 5  10000006  10000006      parcel        D         D    CSS224  ULD40245186
# 6  10000007  10000007      parcel        D         D    CSS224  ULD40245205
# 7  10000008  10000008      parcel        D         D    CSS224  ULD40245189
# 8  10000009  10000009      parcel        D         D    CSS224  ULD40245192
# 9  10000010  10000010      parcel        D         D    CSS224  ULD40245199
#
#           arrive_time send_time plan_disallow_tm actual_disallow_tm src_apt  \
# ...

# %%
od_parcel_small=od_parcel.loc[od_parcel.parcel_type.isin(['small']),['small_id','uld_num','plate_num','src_type','dest_type',]]

# %%
od_parcel_small.head(10)
# Out:
#         small_id      uld_num plate_num src_type dest_type
# 313059  10313060  ULD40245186    CSS224        D         I
# 313060  10313061  ULD40245187    CSS224        D         I
# 313061  10313062  ULD40245200    CSS224        D         I
# 313062  10313063  ULD40245206    CSS224        D         I
# 313063  10313064  ULD40245211    CSS224        D         I
# 313064  10313065  ULD40245196    CSS224        D         I
# 313065  10313066  ULD40245192    CSS224        D         I
# 313066  10313067  ULD40245191    CSS224        D         I
# 313067  10313068  ULD40245203    CSS224        D         I
# 313068  10313069  ULD40245195    CSS224        D         I

# %%
od_parcel_small.src_type = od_parcel_small.src_type.str.replace("INF", "I")
od_parcel_small.dest_type = od_parcel_small.dest_type.str.replace("INF", "I")

# %%
# 根据起始地与目的地分组
g1=od_parcel_small.groupby(['src_type','dest_type'])

# %%
df_dict={}
src_dest=[]
for src_dest_type,group in g1:
    df_dict[src_dest_type]=group
    src_dest.append(src_dest_type)
    print(src_dest_type)
print(src_dest)
# Out:
# ('D', 'I')
# ('D', 'R')
# ('I', 'D')
# ('I', 'I')
# ('I', 'R')
# ('R', 'D')
# ('R', 'I')
# ('R', 'R')
# [('D', 'I'), ('D', 'R'), ('I', 'D'), ('I', 'I'), ('I', 'R'), ('R', 'D'), ('R', 'I'), ('R', 'R')]

# %%
# 空侧
src_dest_air=src_dest[:5]
# 陆侧
src_dest_land=src_dest[5:]

print(len(df_dict[('D', 'I')]['uld_num'].drop_duplicates()))
# Out:
# 1690

# %%
# 处理空侧数据    ('D', 'I'), ('D', 'R'), ('I', 'D'), ('I', 'I'), ('I', 'R')
for i in src_dest_air:
    zz=df_dict[i].reset_index()
    for i,j in zz.groupby(['uld_num']):
        print(i)
        print(j)
        break
    break
# Out:
# ULD40245186
#       index  small_id      uld_num plate_num src_type dest_type
# 0    313059  10313060  ULD40245186    CSS224        D         I
# 19   313078  10313079  ULD40245186    CSS224        D         I
# 56   313115  10313116  ULD40245186    CSS224        D         I
# 133  313192  10313193  ULD40245186    CSS224        D         I
# 193  313252  10313253  ULD40245186    CSS224        D         I
# 283  313342  10313343  ULD40245186    CSS224        D         I
# 287  313346  10313347  ULD40245186    CSS224        D         I
# 309  313368  10313369  ULD40245186    CSS224        D         I
# 337  313396  10313397  ULD40245186    CSS224        D         I
# 432  313491  10313492  ULD40245186    CSS224        D         I
# 449  313508  10313509  ULD40245186    CSS224        D         I
# 454  313513  10313514  ULD40245186    CSS224        D         I
# 477  313536  10313537  ULD40245186    CSS224        D         I
# ...

# %%
# 字典生成式 ，存储空侧主要信息
dic_air={i:{j:[] for j in df_dict[i]['uld_num'].drop_duplicates()} for i in src_dest_air}
dic_land={i:{j:[] for j in df_dict[i]['uld_num'].drop_duplicates()} for i in src_dest_land}
d_i=df_dict[('D', 'I')]
print(dic_air)
# Out:
# {('D', 'I'): {'ULD40245186': [], 'ULD40245187': [], 'ULD40245200': [], 'ULD40245206': [], 'ULD40245211': [], 'ULD40245196': [], 'ULD40245192': [], 'ULD40245191': [], 'ULD40245203': [], 'ULD40245195': [], 'ULD40245198': [], 'ULD40245190': [], 'ULD40245212': [], 'ULD40245208': [], 'ULD40245201': [], 'ULD40245199': [], 'ULD40245202': [], 'ULD40245210': [], 'ULD40245209': [], 'ULD40245194': [], 'ULD40245213': [], 'ULD40245207': [], 'ULD40245204': [], 'ULD40245189': [], 'ULD40245197': [], 'ULD40245188': [], 'ULD40245205': [], 'ULD40245193': [], 'ULD40262751': [], 'ULD40262759': [], 'ULD40262767': [], 'ULD40262766': [], 'ULD40262768': [], 'ULD40262762': [], 'ULD40262763': [], 'ULD40262758': [], 'ULD40262769': [], 'ULD40262757': [], 'ULD40262776': [], 'ULD40262760': [], 'ULD40262752': [], 'ULD40262772': [], 'ULD40262770': [], 'ULD40262771': [], 'ULD40262773': [], 'ULD40262764': [], 'ULD40262761': [], 'ULD40262756': [], 'ULD40262755': [], 'ULD40262765': [], 'ULD40262774': [], 'ULD40262753': 
# ...

# %%
# a=od_parcel.loc[od_parcel.small_id.isin(['10313060']),['uld_num']].reset_index()
# a['uld_num'][0]

# 把D-->I的包裹根据航空箱fenzu
g5=d_i.groupby(['uld_num'])
j=0
for uld_num,gg in g5:
    print(uld_num,gg)
    j+=1
    if j==2:
        break
# Out:
# ULD40245186         small_id      uld_num plate_num src_type dest_type
# 313059  10313060  ULD40245186    CSS224        D         I
# 313078  10313079  ULD40245186    CSS224        D         I
# 313115  10313116  ULD40245186    CSS224        D         I
# 313192  10313193  ULD40245186    CSS224        D         I
# 313252  10313253  ULD40245186    CSS224        D         I
# 313342  10313343  ULD40245186    CSS224        D         I
# 313346  10313347  ULD40245186    CSS224        D         I
# 313368  10313369  ULD40245186    CSS224        D         I
# 313396  10313397  ULD40245186    CSS224        D         I
# 313491  10313492  ULD40245186    CSS224        D         I
# 313508  10313509  ULD40245186    CSS224        D         I
# 313513  10313514  ULD40245186    CSS224        D         I
# 313536  10313537  ULD40245186    CSS224        D         I
# 313582  10313583  ULD40245186    CSS224        D         I
# 313606  10313607  ULD40245186    CSS224        D         I
# ...

# %% [markdown]
# ### 取('D', 'I')断做演示

# %%
# d_i_sid=d_i['small_id']
# d_i_sid.head(5)

# %%
for x in src_dest:
    # x:根据【起始--目的地】的健，获取每一种的信息
    print(df_dict[x]['uld_num'].drop_duplicates())
#     for uld_num,y in df_dict[x].groupby(['uld_num']):
#         print(uld_num)
        
#         break
#     print('============')
   # 再根据
# Out:
# 313059    ULD40245186
# 313060    ULD40245187
# 313061    ULD40245200
# 313062    ULD40245206
# 313063    ULD40245211
# 313064    ULD40245196
# 313065    ULD40245192
# 313066    ULD40245191
# 313067    ULD40245203
# 313068    ULD40245195
# 313069    ULD40245198
# 313070    ULD40245190
# 313071    ULD40245212
# 313073    ULD40245208
# 313074    ULD40245201
# 313075    ULD40245199
# 313077    ULD40245202
# 313083    ULD40245210
# 313086    ULD40245209
# 313093    ULD40245194
# 313096    ULD40245213
# 313104    ULD40245207
# 313107    ULD40245204
# 313114    ULD40245189
# 313116    ULD40245197
# 313117    ULD40245188
# 313131    ULD40245205
# 313142    ULD40245193
# 313717    ULD40262751
# 313718    ULD40262759
#              ...
# 393664    ULD40991285
# 393668    ULD40991268
# 393669    ULD40991284
# 393673    ULD40991265
# 393674    ULD40991258
# 393679    ULD40991276
# 393684    ULD40991275
# 393688    ULD40991270
# 393694    ULD40991283
# 393696    ULD40991260
# ...

# %%
# dic={}
# for small_id in list(d_i_sid):
#     # 根据small_id读取uld_num,这是parcel_id的第1部分
#     a1=od_parcel.loc[od_parcel.small_id.isin([small_id]),['uld_num']].reset_index()
#     uld_id=a1['uld_num'][0]
#    # 根据small_id读取parcel_type，这是parcel_id的第2部分
#     a2=od_parcel.loc[od_parcel.small_id.isin([small_id]),['parcel_type']].reset_index()
#     parcel_type=a2['parcel_type'][0]
#     print(small_id,uld_id,parcel_type)
    
#     dic[uld_id+parcel_type[:1]]=[]
